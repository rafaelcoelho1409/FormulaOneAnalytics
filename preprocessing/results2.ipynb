# %%
import pandas as pd
import os
import datetime as dt
from dateutil.relativedelta import relativedelta
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %%
results = pd.read_pickle("../data/results.pkl")

# %%
results.head()
# Out:
#    resultId  raceId  driverId  constructorId number_driver  grid position  \
# 0         1      18         1              1            22     1        1
# 1         2      18         2              2             3     5        2
# 2         3      18         3              3             7     7        3
# 3         4      18         4              4             5    11        4
# 4         5      18         5              1            23     3        5
#
#   positionText  positionOrder  points  laps total_race_time milliseconds  \
# 0            1              1    10.0    58     1:34:50.616      5690616
# 1            2              2     8.0    58          +5.478      5696094
# 2            3              3     6.0    58          +8.163      5698779
# 3            4              4     5.0    58         +17.181      5707797
# 4            5              5     4.0    58         +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId  year  round  \
# 0         39    2       1:27.452         218.300         1  2008      1
# 1         41    3       1:27.739         217.586         1  2008      1
# 2         41    5       1:28.090         216.719         1  2008      1
# 3         58    7       1:28.603         215.464         1  2008      1
# 4         43    1       1:27.418         218.385         1  2008      1
#
#    circuitId              name_race        date race_time  \
# 0          1  Australian Grand Prix  2008-03-16  04:30:00
# 1          1  Australian Grand Prix  2008-03-16  04:30:00
# 2          1  Australian Grand Prix  2008-03-16  04:30:00
# 3          1  Australian Grand Prix  2008-03-16  04:30:00
# 4          1  Australian Grand Prix  2008-03-16  04:30:00
#
#                                             url_race fp1_date fp1_time  \
# 0  http://en.wikipedia.org/wiki/2008_Australian_G...       \N       \N
# 1  http://en.wikipedia.org/wiki/2008_Australian_G...       \N       \N
# 2  http://en.wikipedia.org/wiki/2008_Australian_G...       \N       \N
# 3  http://en.wikipedia.org/wiki/2008_Australian_G...       \N       \N
# 4  http://en.wikipedia.org/wiki/2008_Australian_G...       \N       \N
#
#   fp2_date fp2_time fp3_date fp3_time quali_date quali_time sprint_date  \
# 0       \N       \N       \N       \N         \N         \N          \N
# 1       \N       \N       \N       \N         \N         \N          \N
# 2       \N       \N       \N       \N         \N         \N          \N
# 3       \N       \N       \N       \N         \N         \N          \N
# 4       \N       \N       \N       \N         \N         \N          \N
#
#   sprint_time   driverRef code  forename     surname         dob  \
# 0          \N    hamilton  HAM     Lewis    Hamilton  1985-01-07
# 1          \N    heidfeld  HEI      Nick    Heidfeld  1977-05-10
# 2          \N     rosberg  ROS      Nico     Rosberg  1985-06-27
# 3          \N      alonso  ALO  Fernando      Alonso  1981-07-29
# 4          \N  kovalainen  KOV    Heikki  Kovalainen  1981-10-19
#
#   driver_nationality                                      url_driver  \
# 0            British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1             German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2             German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3            Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4            Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen
#
#   constructorRef constructor_name constructor_nationality  \
# 0        mclaren          McLaren                 British
# 1     bmw_sauber       BMW Sauber                  German
# 2       williams         Williams                 British
# 3        renault          Renault                  French
# 4        mclaren          McLaren                 British
#
#                                      url_constructor    status   circuitRef  \
# 0               http://en.wikipedia.org/wiki/McLaren  Finished  albert_park
# 1            http://en.wikipedia.org/wiki/BMW_Sauber  Finished  albert_park
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...  Finished  albert_park
# 3  http://en.wikipedia.org/wiki/Renault_in_Formul...  Finished  albert_park
# 4               http://en.wikipedia.org/wiki/McLaren  Finished  albert_park
#
#                      circuit_name   location    country      lat      lng alt  \
# 0  Albert Park Grand Prix Circuit  Melbourne  Australia -37.8497  144.968  10
# 1  Albert Park Grand Prix Circuit  Melbourne  Australia -37.8497  144.968  10
# 2  Albert Park Grand Prix Circuit  Melbourne  Australia -37.8497  144.968  10
# 3  Albert Park Grand Prix Circuit  Melbourne  Australia -37.8497  144.968  10
# 4  Albert Park Grand Prix Circuit  Melbourne  Australia -37.8497  144.968  10
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 2  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 3  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 4  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
